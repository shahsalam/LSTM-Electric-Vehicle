# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import randint
import seaborn as sns # used for plot interactive graph.
import math
import pytz

from sklearn.model_selection import train_test_split # to split the data into two parts
from sklearn.model_selection import KFold # use for cross validation
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score

## RNN:
import keras
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam, AdamW, Adamax,SGD
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM, GRU
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout # Careful
from keras.layers import BatchNormalization

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_main = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/Electric_Vehicle_Charging_Station_Energy_Consumption_Smooth.csv', delimiter=",")
data_main.reindex(np.arange(len(data_main)))
data_main.reset_index(drop=True)
# Out:
#                       Station_Name            Address     City State_Province  \
# 0           BOULDER / BASELINE ST1    900 Baseline Rd  Boulder       Colorado
# 1           BOULDER / BASELINE ST1    900 Baseline Rd  Boulder       Colorado
# 2           BOULDER / JUNCTION ST1   2280 Junction Pl  Boulder       Colorado
# 3         BOULDER / REC CENTER ST1  1360 Gillaspie Dr  Boulder       Colorado
# 4           BOULDER / JUNCTION ST1   2280 Junction Pl  Boulder       Colorado
# ...                            ...                ...      ...            ...
# 39807    BOULDER / CARPENTER PARK1       1505 30th St  Boulder       Colorado
# 39808  COMM VITALITY / 1100WALNUT1        1100 Walnut  Boulder       Colorado
# 39809  COMM VITALITY / 1100WALNUT1        1100 Walnut  Boulder       Colorado
# 39810    BOULDER / CARPENTER PARK2       1505 30th St  Boulder       Colorado
# 39811   COMM VITALITY / 1500PEARL2      1500 Pearl St  Boulder       Colorado
#
#        Zip_Postal_Code       Start_Date___Time Start_Time_Zone  \
# 0                80302  2018/01/20 07:29:00+00             MDT
# 1                80302  2018/01/20 11:42:00+00             MDT
# 2                80301  2018/01/20 11:51:00+00             MDT
# 3                80305  2018/01/20 14:54:00+00             MDT
# 4                80301  2018/01/20 20:21:00+00             MDT
# ...                ...                     ...             ...
# 39807            80303  2022/07/31 18:51:00+00             MDT
# 39808            80302  2022/07/31 19:08:00+00             MDT
# 39809            80302  2022/07/31 19:25:00+00             MDT
# 39810            80303  2022/07/31 21:44:00+00             MDT
# 39811            80302  2022/07/31 23:39:00+00             MDT
#
#               End_Date___Time End_Time_Zone Total_Duration__hh_mm_ss_  \
# 0      2018/01/20 09:22:00+00           MDT                   1:52:59
# 1      2018/01/20 15:27:00+00           MDT                   3:45:39
# 2      2018/01/20 12:54:00+00           MDT                   1:03:01
# 3      2018/01/20 15:52:00+00           MDT                   0:58:33
# 4      2018/01/21 08:06:00+00           MDT                  11:44:35
# ...                       ...           ...                       ...
# 39807  2022/07/31 21:31:00+00           MDT                   2:39:58
# 39808  2022/07/31 20:14:00+00           MDT                   1:06:27
# 39809  2022/07/31 20:38:00+00           MDT                   1:12:50
# 39810  2022/07/31 23:49:00+00           MDT                   2:04:26
# 39811  2022/08/01 11:10:00+00           MDT                  11:31:24
#
#       Charging_Time__hh_mm_ss_  Energy__kWh_  GHG_Savings__kg_  \
# 0                      1:52:41          4.61              1.94
# 1                      2:22:15          4.61              2.81
# 2                      1:02:50          4.61              2.88
# 3                      0:58:25          3.98              1.67
# 4                      3:09:24          5.88              2.47
# ...                        ...           ...               ...
# 39807                  2:39:29          6.05              4.30
# 39808                  1:06:03          4.49              3.19
# 39809                  1:10:41          6.86              4.87
# 39810                  2:04:10          9.48              6.73
# 39811                  2:20:27         12.94              9.19
#
#        Gasoline_Savings__gallons_ Port_Type  ObjectId
# 0                            0.58   Level 2         1
# 1                            0.84   Level 2         2
# 2                            0.86   Level 2         3
# 3                            0.50   Level 2         5
# 4                            0.74   Level 2         6
# ...                           ...       ...       ...
# 39807                        0.76   Level 2     43655
# 39808                        0.56   Level 2     43656
# 39809                        0.86   Level 2     43657
# 39810                        1.19   Level 2     43658
# 39811                        1.62   Level 2     43659
#
# [39812 rows x 16 columns]

# %%
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39812 entries, 0 to 39811
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Station_Name                39812 non-null  object
#  1   Address                     39812 non-null  object
#  2   City                        39812 non-null  object
#  3   State_Province              39812 non-null  object
#  4   Zip_Postal_Code             39812 non-null  int64
#  5   Start_Date___Time           39812 non-null  object
#  6   Start_Time_Zone             39812 non-null  object
#  7   End_Date___Time             39812 non-null  object
#  8   End_Time_Zone               39812 non-null  object
#  9   Total_Duration__hh_mm_ss_   39812 non-null  object
#  10  Charging_Time__hh_mm_ss_    39812 non-null  object
#  11  Energy__kWh_                39812 non-null  float64
#  12  GHG_Savings__kg_            39812 non-null  float64
#  13  Gasoline_Savings__gallons_  39812 non-null  float64
#  14  Port_Type                   39812 non-null  object
#  15  ObjectId                    39812 non-null  int64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 4.9+ MB

# %%
#Correlation Map
import seaborn as sns
plt.figure(figsize=(7,5));
a = sns.heatmap(data_main.corr(), annot=True, fmt=".2f", annot_kws={"size": 10});
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=60)
plt.show();
# Out:
# <ipython-input-6-8b948964c71a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a = sns.heatmap(data_main.corr(), annot=True, fmt=".2f", annot_kws={"size": 10});

# %%
data_main = data_main.drop(['Station_Name','Address','City','State_Province','Start_Time_Zone','End_Date___Time','End_Time_Zone','Total_Duration__hh_mm_ss_','Charging_Time__hh_mm_ss_','Port_Type','ObjectId','Zip_Postal_Code'], axis=1)

# %%
data_main
# Out:
#             Start_Date___Time  Energy__kWh_  GHG_Savings__kg_  \
# 0      2018/01/20 07:29:00+00          4.61              1.94
# 1      2018/01/20 11:42:00+00          4.61              2.81
# 2      2018/01/20 11:51:00+00          4.61              2.88
# 3      2018/01/20 14:54:00+00          3.98              1.67
# 4      2018/01/20 20:21:00+00          5.88              2.47
# ...                       ...           ...               ...
# 39807  2022/07/31 18:51:00+00          6.05              4.30
# 39808  2022/07/31 19:08:00+00          4.49              3.19
# 39809  2022/07/31 19:25:00+00          6.86              4.87
# 39810  2022/07/31 21:44:00+00          9.48              6.73
# 39811  2022/07/31 23:39:00+00         12.94              9.19
#
#        Gasoline_Savings__gallons_
# 0                            0.58
# 1                            0.84
# 2                            0.86
# 3                            0.50
# 4                            0.74
# ...                           ...
# 39807                        0.76
# 39808                        0.56
# 39809                        0.86
# 39810                        1.19
# 39811                        1.62
#
# [39812 rows x 4 columns]

# %%
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39812 entries, 0 to 39811
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Start_Date___Time           39812 non-null  object
#  1   Energy__kWh_                39812 non-null  float64
#  2   GHG_Savings__kg_            39812 non-null  float64
#  3   Gasoline_Savings__gallons_  39812 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 1.2+ MB

# %%
data_main = data_main
data_main["DateTime"] = pd.to_datetime(data_main["Start_Date___Time"])
data_main.set_index("DateTime", drop=True, inplace=True)
data_main = data_main.drop(['Start_Date___Time'], axis=1)
data_main.sort_index(inplace=True)
data_main.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/Electric_Data.csv')

# %%
data_main
# Out:
#                            Energy__kWh_  GHG_Savings__kg_  \
# DateTime
# 2018-01-01 17:49:00+00:00          7.69              3.23
# 2018-01-02 08:52:00+00:00          4.49              1.89
# 2018-01-02 21:11:00+00:00          8.76              3.68
# 2018-01-03 09:19:00+00:00         11.00              4.62
# 2018-01-03 14:13:00+00:00          4.37              1.84
# ...                                 ...               ...
# 2022-07-31 18:51:00+00:00          6.05              4.30
# 2022-07-31 19:08:00+00:00          4.49              3.19
# 2022-07-31 19:25:00+00:00          6.86              4.87
# 2022-07-31 21:44:00+00:00          9.48              6.73
# 2022-07-31 23:39:00+00:00         12.94              9.19
#
#                            Gasoline_Savings__gallons_
# DateTime
# 2018-01-01 17:49:00+00:00                        0.96
# 2018-01-02 08:52:00+00:00                        0.56
# 2018-01-02 21:11:00+00:00                        1.10
# 2018-01-03 09:19:00+00:00                        1.38
# 2018-01-03 14:13:00+00:00                        0.55
# ...                                               ...
# 2022-07-31 18:51:00+00:00                        0.76
# 2022-07-31 19:08:00+00:00                        0.56
# 2022-07-31 19:25:00+00:00                        0.86
# 2022-07-31 21:44:00+00:00                        1.19
# 2022-07-31 23:39:00+00:00                        1.62
#
# [39812 rows x 3 columns]

# %%
df2=data_main.resample('360min').agg({"Energy__kWh_":"sum","GHG_Savings__kg_":"sum","Gasoline_Savings__gallons_":"sum"})

# %%
for x in ['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_']:
    q75,q25 = np.percentile(df2.loc[:,x],[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    df2.loc[df2[x] < min,x] = np.nan
    df2.loc[df2[x] > max,x] = np.nan

# %%
df2.isnull().sum()
# Out:
# Energy__kWh_                  198
# GHG_Savings__kg_              473
# Gasoline_Savings__gallons_    198
# dtype: int64

# %%
df2
# Out:
#                            Energy__kWh_  GHG_Savings__kg_  \
# DateTime
# 2018-01-01 12:00:00+00:00          7.69              3.23
# 2018-01-01 18:00:00+00:00          0.00              0.00
# 2018-01-02 00:00:00+00:00          0.00              0.00
# 2018-01-02 06:00:00+00:00          4.49              1.89
# 2018-01-02 12:00:00+00:00          0.00              0.00
# ...                                 ...               ...
# 2022-07-30 18:00:00+00:00         91.54             65.00
# 2022-07-31 00:00:00+00:00         12.34              8.76
# 2022-07-31 06:00:00+00:00        151.92               NaN
# 2022-07-31 12:00:00+00:00           NaN               NaN
# 2022-07-31 18:00:00+00:00         54.10             38.41
#
#                            Gasoline_Savings__gallons_
# DateTime
# 2018-01-01 12:00:00+00:00                        0.96
# 2018-01-01 18:00:00+00:00                        0.00
# 2018-01-02 00:00:00+00:00                        0.00
# 2018-01-02 06:00:00+00:00                        0.56
# 2018-01-02 12:00:00+00:00                        0.00
# ...                                               ...
# 2022-07-30 18:00:00+00:00                       11.49
# 2022-07-31 00:00:00+00:00                        1.55
# 2022-07-31 06:00:00+00:00                       19.07
# 2022-07-31 12:00:00+00:00                         NaN
# 2022-07-31 18:00:00+00:00                        6.78
#
# [6690 rows x 3 columns]

# %%
df2.fillna(df2.dtypes.replace({'float64': 0.000, 'O': 'NULL'}), inplace=True)
df2.replace(0, np.nan, inplace=True)

# %%
df2.dropna(subset=['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_'], inplace = True)

# %%
df2
# Out:
#                            Energy__kWh_  GHG_Savings__kg_  \
# DateTime
# 2018-01-01 12:00:00+00:00          7.69              3.23
# 2018-01-02 06:00:00+00:00          4.49              1.89
# 2018-01-02 18:00:00+00:00          8.76              3.68
# 2018-01-03 06:00:00+00:00         11.00              4.62
# 2018-01-03 12:00:00+00:00          6.51              2.74
# ...                                 ...               ...
# 2022-07-29 18:00:00+00:00         70.08             49.76
# 2022-07-30 00:00:00+00:00          5.40              3.83
# 2022-07-30 18:00:00+00:00         91.54             65.00
# 2022-07-31 00:00:00+00:00         12.34              8.76
# 2022-07-31 18:00:00+00:00         54.10             38.41
#
#                            Gasoline_Savings__gallons_
# DateTime
# 2018-01-01 12:00:00+00:00                        0.96
# 2018-01-02 06:00:00+00:00                        0.56
# 2018-01-02 18:00:00+00:00                        1.10
# 2018-01-03 06:00:00+00:00                        1.38
# 2018-01-03 12:00:00+00:00                        0.82
# ...                                               ...
# 2022-07-29 18:00:00+00:00                        8.81
# 2022-07-30 00:00:00+00:00                        0.68
# 2022-07-30 18:00:00+00:00                       11.49
# 2022-07-31 00:00:00+00:00                        1.55
# 2022-07-31 18:00:00+00:00                        6.78
#
# [4700 rows x 3 columns]

# %%
df2["EV_lag_1"] = df2["Energy__kWh_"].shift(-1)
df2["EV_lag_2"] = df2["Energy__kWh_"].shift(-2)
df2["EV_lag_3"] = df2["Energy__kWh_"].shift(-3)
#df2["EV_lag_4"] = df2["Energy__kWh_"].shift(-4)
#df2["EV_lag_5"] = df2["Energy__kWh_"].shift(-5)
#df2["EV_lag_6"] = df2["Energy__kWh_"].shift(-6)

# %%
df2=df2.reset_index()

# %%
# We have every 4hours of data ready now
df3=df2.filter(['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_','EV_lag_1','EV_lag_2','EV_lag_3'], axis=1)
df3
# Out:
#       Energy__kWh_  GHG_Savings__kg_  Gasoline_Savings__gallons_  EV_lag_1  \
# 0             7.69              3.23                        0.96      4.49
# 1             4.49              1.89                        0.56      8.76
# 2             8.76              3.68                        1.10     11.00
# 3            11.00              4.62                        1.38      6.51
# 4             6.51              2.74                        0.82      3.46
# ...            ...               ...                         ...       ...
# 4695         70.08             49.76                        8.81      5.40
# 4696          5.40              3.83                        0.68     91.54
# 4697         91.54             65.00                       11.49     12.34
# 4698         12.34              8.76                        1.55     54.10
# 4699         54.10             38.41                        6.78       NaN
#
#       EV_lag_2  EV_lag_3
# 0         8.76     11.00
# 1        11.00      6.51
# 2         6.51      3.46
# 3         3.46     25.90
# 4        25.90     19.89
# ...        ...       ...
# 4695     91.54     12.34
# 4696     12.34     54.10
# 4697     54.10       NaN
# 4698       NaN       NaN
# 4699       NaN       NaN
#
# [4700 rows x 6 columns]

# %%
missing_col = ['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_','EV_lag_1','EV_lag_2','EV_lag_3']
#Technique 1: Using mean to impute the missing values
for i in missing_col:
 df3.loc[df3.loc[:,i].isnull(),i]=df3.loc[:,i].mean()

# %%
df3
# Out:
#       Energy__kWh_  GHG_Savings__kg_  Gasoline_Savings__gallons_   EV_lag_1  \
# 0             7.69              3.23                        0.96   4.490000
# 1             4.49              1.89                        0.56   8.760000
# 2             8.76              3.68                        1.10  11.000000
# 3            11.00              4.62                        1.38   6.510000
# 4             6.51              2.74                        0.82   3.460000
# ...            ...               ...                         ...        ...
# 4695         70.08             49.76                        8.81   5.400000
# 4696          5.40              3.83                        0.68  91.540000
# 4697         91.54             65.00                       11.49  12.340000
# 4698         12.34              8.76                        1.55  54.100000
# 4699         54.10             38.41                        6.78  53.309915
#
#        EV_lag_2   EV_lag_3
# 0      8.760000  11.000000
# 1     11.000000   6.510000
# 2      6.510000   3.460000
# 3      3.460000  25.900000
# 4     25.900000  19.890000
# ...         ...        ...
# 4695  91.540000  12.340000
# 4696  12.340000  54.100000
# 4697  54.100000  53.329793
# 4698  53.320307  53.329793
# 4699  53.320307  53.329793
#
# [4700 rows x 6 columns]

# %%
df3.drop(df3.tail(20).index,inplace = True)

# %%
#df3 is our final dataset we need to use to predict the next days first 1440 hours of charging
df3
# Out:
#       Energy__kWh_  GHG_Savings__kg_  Gasoline_Savings__gallons_  EV_lag_1  \
# 0             7.69              3.23                        0.96      4.49
# 1             4.49              1.89                        0.56      8.76
# 2             8.76              3.68                        1.10     11.00
# 3            11.00              4.62                        1.38      6.51
# 4             6.51              2.74                        0.82      3.46
# ...            ...               ...                         ...       ...
# 4675         74.99             53.25                        9.41     14.79
# 4676         14.79             10.50                        1.86    100.71
# 4677        100.71             71.51                       12.65     11.04
# 4678         11.04              7.84                        1.38     69.86
# 4679         69.86             49.61                        8.78      3.50
#
#       EV_lag_2  EV_lag_3
# 0         8.76     11.00
# 1        11.00      6.51
# 2         6.51      3.46
# 3         3.46     25.90
# 4        25.90     19.89
# ...        ...       ...
# 4675    100.71     11.04
# 4676     11.04     69.86
# 4677     69.86      3.50
# 4678      3.50     90.78
# 4679     90.78     40.62
#
# [4680 rows x 6 columns]

# %%
# Hour 75%
#train=df3[0:32744]
#test=df3[32744:40128]

# 80% Day
train=df3[0:3509]
test=df3[3509:4680]

# %%
test.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/Test_Data.csv')

# %%
#train_X=train[['Energy__kWh_','GHG_Savings__kg_','EV_lag_1','EV_lag_2','EV_lag_3','EV_lag_4','EV_lag_5']]

# %%
#train_X=train[['GHG_Savings__kg_','Gasoline_Savings__gallons_','EV_lag_1','EV_lag_2','EV_lag_3','EV_lag_4','EV_lag_5','EV_lag_6']]

# %%
train_X=train[['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_','EV_lag_1','EV_lag_2']]
train_y=train[['EV_lag_3']]
#train_y=train[['Energy__kWh_']]
test_X=test[['Energy__kWh_','GHG_Savings__kg_','Gasoline_Savings__gallons_','EV_lag_1','EV_lag_2']]
test_y=test[['EV_lag_3']]
#test_y=test[['Energy__kWh_']]

# %%
#Scaling has to be done for LSTM
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc2= StandardScaler()
train_X_sc=sc.fit_transform(train_X)
train_y_sc=sc2.fit_transform(train_y)
test_X_sc=sc.transform(test_X)
test_y_sc=X_test = sc2.transform(test_y)

# %%
train_X_sc = pd.DataFrame(train_X_sc)
train_y_sc = pd.DataFrame(train_y_sc)
test_X_sc = pd.DataFrame(test_X_sc)
test_y_sc = pd.DataFrame(test_y_sc)

# %%
# create and fit the LSTM network 1
model = Sequential()
model.add(LSTM(8, input_shape=(5,1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='Adam')
model.fit(train_X_sc, train_y_sc, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 3509/3509 - 10s - loss: 0.9063 - 10s/epoch - 3ms/step
# Epoch 2/100
# 3509/3509 - 9s - loss: 0.8846 - 9s/epoch - 3ms/step
# Epoch 3/100
# 3509/3509 - 11s - loss: 0.8611 - 11s/epoch - 3ms/step
# Epoch 4/100
# 3509/3509 - 8s - loss: 0.8431 - 8s/epoch - 2ms/step
# Epoch 5/100
# 3509/3509 - 9s - loss: 0.8321 - 9s/epoch - 3ms/step
# Epoch 6/100
# 3509/3509 - 9s - loss: 0.8264 - 9s/epoch - 3ms/step
# Epoch 7/100
# 3509/3509 - 8s - loss: 0.8244 - 8s/epoch - 2ms/step
# Epoch 8/100
# 3509/3509 - 10s - loss: 0.8186 - 10s/epoch - 3ms/step
# Epoch 9/100
# 3509/3509 - 9s - loss: 0.8177 - 9s/epoch - 3ms/step
# Epoch 10/100
# 3509/3509 - 9s - loss: 0.8167 - 9s/epoch - 2ms/step
# Epoch 11/100
# 3509/3509 - 9s - loss: 0.8150 - 9s/epoch - 3ms/step
# Epoch 12/100
# 3509/3509 - 8s - loss: 0.8126 - 8s/epoch - 2ms/step
# Epoch 13/100
# 3509/3509 - 9s - loss: 0.8124 - 9s/epoch - 3ms/step
# Epoch 14/100
# 3509/3509 - 9s - loss: 0.8127 - 9s/epoch - 3ms/step
# Epoch 15/100
# 3509/3509 - 8s - loss: 0.8093 - 8s/epoch - 2ms/step
# Epoch 16/100
# 3509/3509 - 9s - loss: 0.8105 - 9s/epoch - 3ms/step
# Epoch 17/100
# 3509/3509 - 8s - loss: 0.8085 - 8s/epoch - 2ms/step
# Epoch 18/100

# %%
# make predictions
trainPredict = pd.DataFrame(model.predict(train_X_sc))
testPredict = pd.DataFrame(model.predict(test_X_sc))
# Out:
# 110/110 [==============================] - 1s 2ms/step
# 37/37 [==============================] - 0s 3ms/step

# %%
# invert predictions
trainPredict = sc2.inverse_transform(trainPredict)
testPredict = sc2.inverse_transform(testPredict)

# %%
trainPredict = pd.DataFrame(trainPredict)
testPredict = pd.DataFrame(testPredict)

# %%
#invert train y and test y
train_y_plot = pd.DataFrame(sc2.inverse_transform(train_y_sc))
test_y_plot = pd.DataFrame(sc2.inverse_transform(test_y_sc))

# %%
trainScore = math.sqrt(mean_squared_error(train_y_plot, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(test_y_plot, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 33.53 RMSE
# Test Score: 43.22 RMSE

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(train_y_plot, trainPredict)
# Out:
# 0.22845592817534677

# %%
# plot baseline and predictions
plt.plot(train_y_plot)
plt.plot(trainPredict)
plt.show()

# %%
train_y_plot.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/Trainy.csv')
trainPredict.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/TrainPredict.csv')

# %%
plt.plot(test_y_plot)
plt.plot(testPredict)
plt.show()

# %%
test_y_plot.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/Testy.csv')
testPredict.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/TestPredict.csv')

# %%
from numpy import savetxt
# save to csv file
savetxt('features.csv', trainPredict, delimiter=',')
savetxt('features2.csv', train_y_plot, delimiter=',')

# %%
# MAPE function
def mape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

def median_ape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.median(np.abs((actual - pred) / actual)) * 100

# %%
# Calculate MAPE
mape_train = mape(train_y_plot+0.01, trainPredict)
mape_test = mape(test_y_plot+0.01, testPredict)
print("MAPE of training set:",np.round(mape_train,2), "MAPE of testing set:", np.round(mape_test,2))
# Out:
# MAPE of training set: 140.65 MAPE of testing set: 155.59

# %%
# create and fit the LSTM network 2
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(5,1)))
model.add(LSTM(16))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(1))
optimizer = Adam(clipvalue=2.0)
model.compile(loss='mean_squared_error', optimizer=optimizer)
#model.compile(loss='mean_absolute_error', optimizer=optimizer)

model.fit(train_X_sc, train_y_sc, epochs=100, batch_size=8, verbose=2)
# Out:
# Epoch 1/100
# 439/439 - 7s - loss: 1.0367 - 7s/epoch - 16ms/step
# Epoch 2/100
# 439/439 - 3s - loss: 0.9298 - 3s/epoch - 8ms/step
# Epoch 3/100
# 439/439 - 4s - loss: 0.8874 - 4s/epoch - 9ms/step
# Epoch 4/100
# 439/439 - 3s - loss: 0.8718 - 3s/epoch - 7ms/step
# Epoch 5/100
# 439/439 - 3s - loss: 0.8672 - 3s/epoch - 7ms/step
# Epoch 6/100
# 439/439 - 3s - loss: 0.8623 - 3s/epoch - 7ms/step
# Epoch 7/100
# 439/439 - 4s - loss: 0.8666 - 4s/epoch - 10ms/step
# Epoch 8/100
# 439/439 - 3s - loss: 0.8604 - 3s/epoch - 7ms/step
# Epoch 9/100
# 439/439 - 3s - loss: 0.8550 - 3s/epoch - 7ms/step
# Epoch 10/100
# 439/439 - 3s - loss: 0.8553 - 3s/epoch - 7ms/step
# Epoch 11/100
# 439/439 - 4s - loss: 0.8564 - 4s/epoch - 10ms/step
# Epoch 12/100
# 439/439 - 3s - loss: 0.8535 - 3s/epoch - 7ms/step
# Epoch 13/100
# 439/439 - 3s - loss: 0.8519 - 3s/epoch - 7ms/step
# Epoch 14/100
# 439/439 - 3s - loss: 0.8527 - 3s/epoch - 7ms/step
# Epoch 15/100
# 439/439 - 4s - loss: 0.8536 - 4s/epoch - 9ms/step
# Epoch 16/100
# 439/439 - 3s - loss: 0.8528 - 3s/epoch - 8ms/step
# Epoch 17/100
# 439/439 - 3s - loss: 0.8547 - 3s/epoch - 7ms/step
# Epoch 18/100
# 439/439 - 3s - loss: 0.8550 - 3s/epoch - 7ms/step
# Epoch 19/100
# 439/439 - 4s - loss: 0.8490 - 4s/epoch - 8ms/step
# Epoch 20/100
# 439/439 - 4s - loss: 0.8537 - 4s/epoch - 8ms/step
# Epoch 21/100
# 439/439 - 3s - loss: 0.8468 - 3s/epoch - 7ms/step
# Epoch 22/100
# 439/439 - 3s - loss: 0.8486 - 3s/epoch - 7ms/step
# Epoch 23/100
# 439/439 - 3s - loss: 0.8497 - 3s/epoch - 8ms/step
# Epoch 24/100
# 439/439 - 4s - loss: 0.8413 - 4s/epoch - 9ms/step
# Epoch 25/100
# 439/439 - 3s - loss: 0.8386 - 3s/epoch - 7ms/step
# Epoch 26/100
# 439/439 - 3s - loss: 0.8490 - 3s/epoch - 7ms/step
# Epoch 27/100
# 439/439 - 3s - loss: 0.8478 - 3s/epoch - 7ms/step
# Epoch 28/100
# 439/439 - 4s - loss: 0.8431 - 4s/epoch - 10ms/step
# Epoch 29/100
# 439/439 - 3s - loss: 0.8417 - 3s/epoch - 7ms/step
# Epoch 30/100
# 439/439 - 3s - loss: 0.8459 - 3s/epoch - 7ms/step
# Epoch 31/100
# 439/439 - 3s - loss: 0.8464 - 3s/epoch - 7ms/step
# Epoch 32/100
# 439/439 - 4s - loss: 0.8426 - 4s/epoch - 10ms/step
# Epoch 33/100
# 439/439 - 3s - loss: 0.8413 - 3s/epoch - 7ms/step
# Epoch 34/100
# 439/439 - 3s - loss: 0.8529 - 3s/epoch - 7ms/step
# Epoch 35/100
# 439/439 - 3s - loss: 0.8365 - 3s/epoch - 7ms/step
# Epoch 36/100
# 439/439 - 4s - loss: 0.8364 - 4s/epoch - 9ms/step
# Epoch 37/100
# 439/439 - 3s - loss: 0.8332 - 3s/epoch - 8ms/step
# Epoch 38/100
# 439/439 - 3s - loss: 0.8337 - 3s/epoch - 7ms/step
# Epoch 39/100
# 439/439 - 3s - loss: 0.8334 - 3s/epoch - 7ms/step
# Epoch 40/100
# 439/439 - 4s - loss: 0.8427 - 4s/epoch - 8ms/step
# Epoch 41/100
# 439/439 - 4s - loss: 0.8369 - 4s/epoch - 9ms/step
# Epoch 42/100
# 439/439 - 3s - loss: 0.8450 - 3s/epoch - 7ms/step
# Epoch 43/100
# 439/439 - 3s - loss: 0.8339 - 3s/epoch - 7ms/step
# Epoch 44/100
# 439/439 - 3s - loss: 0.8400 - 3s/epoch - 8ms/step
# Epoch 45/100
# 439/439 - 4s - loss: 0.8472 - 4s/epoch - 9ms/step
# Epoch 46/100
# 439/439 - 3s - loss: 0.8395 - 3s/epoch - 7ms/step
# Epoch 47/100
# 439/439 - 3s - loss: 0.8347 - 3s/epoch - 7ms/step
# Epoch 48/100
# 439/439 - 3s - loss: 0.8291 - 3s/epoch - 7ms/step
# Epoch 49/100
# 439/439 - 4s - loss: 0.8434 - 4s/epoch - 10ms/step
# Epoch 50/100
# 439/439 - 3s - loss: 0.8382 - 3s/epoch - 7ms/step
# Epoch 51/100
# 439/439 - 3s - loss: 0.8295 - 3s/epoch - 7ms/step
# Epoch 52/100
# 439/439 - 3s - loss: 0.8375 - 3s/epoch - 7ms/step
# Epoch 53/100
# 439/439 - 4s - loss: 0.8374 - 4s/epoch - 10ms/step
# Epoch 54/100
# 439/439 - 4s - loss: 0.8315 - 4s/epoch - 10ms/step
# Epoch 55/100
# 439/439 - 3s - loss: 0.8245 - 3s/epoch - 7ms/step
# Epoch 56/100
# 439/439 - 3s - loss: 0.8287 - 3s/epoch - 7ms/step
# Epoch 57/100
# 439/439 - 4s - loss: 0.8273 - 4s/epoch - 10ms/step
# Epoch 58/100
# 439/439 - 3s - loss: 0.8400 - 3s/epoch - 7ms/step
# Epoch 59/100
# 439/439 - 3s - loss: 0.8217 - 3s/epoch - 7ms/step
# Epoch 60/100
# 439/439 - 3s - loss: 0.8468 - 3s/epoch - 7ms/step
# Epoch 61/100
# 439/439 - 4s - loss: 0.8280 - 4s/epoch - 9ms/step
# Epoch 62/100
# 439/439 - 3s - loss: 0.8251 - 3s/epoch - 7ms/step
# Epoch 63/100
# 439/439 - 3s - loss: 0.8340 - 3s/epoch - 7ms/step
# Epoch 64/100
# 439/439 - 3s - loss: 0.8299 - 3s/epoch - 7ms/step
# Epoch 65/100
# 439/439 - 4s - loss: 0.8257 - 4s/epoch - 9ms/step
# Epoch 66/100
# 439/439 - 4s - loss: 0.8289 - 4s/epoch - 8ms/step
# Epoch 67/100
# 439/439 - 3s - loss: 0.8403 - 3s/epoch - 7ms/step
# Epoch 68/100
# 439/439 - 3s - loss: 0.8233 - 3s/epoch - 7ms/step
# Epoch 69/100
# 439/439 - 4s - loss: 0.8256 - 4s/epoch - 8ms/step
# Epoch 70/100
# 439/439 - 4s - loss: 0.8179 - 4s/epoch - 9ms/step
# Epoch 71/100
# 439/439 - 3s - loss: 0.8308 - 3s/epoch - 7ms/step
# Epoch 72/100
# 439/439 - 3s - loss: 0.8378 - 3s/epoch - 7ms/step
# Epoch 73/100
# 439/439 - 3s - loss: 0.8278 - 3s/epoch - 7ms/step
# Epoch 74/100
# 439/439 - 4s - loss: 0.8295 - 4s/epoch - 9ms/step
# Epoch 75/100
# 439/439 - 3s - loss: 0.8321 - 3s/epoch - 7ms/step
# Epoch 76/100
# 439/439 - 3s - loss: 0.8261 - 3s/epoch - 7ms/step
# Epoch 77/100
# 439/439 - 3s - loss: 0.8209 - 3s/epoch - 7ms/step
# Epoch 78/100
# 439/439 - 4s - loss: 0.8240 - 4s/epoch - 10ms/step
# Epoch 79/100
# 439/439 - 3s - loss: 0.8200 - 3s/epoch - 7ms/step
# Epoch 80/100
# 439/439 - 3s - loss: 0.8186 - 3s/epoch - 7ms/step
# Epoch 81/100
# 439/439 - 3s - loss: 0.8197 - 3s/epoch - 7ms/step
# Epoch 82/100
# 439/439 - 4s - loss: 0.8222 - 4s/epoch - 10ms/step
# Epoch 83/100
# 439/439 - 3s - loss: 0.8297 - 3s/epoch - 7ms/step
# Epoch 84/100
# 439/439 - 3s - loss: 0.8312 - 3s/epoch - 7ms/step
# Epoch 85/100
# 439/439 - 3s - loss: 0.8245 - 3s/epoch - 7ms/step
# Epoch 86/100
# 439/439 - 4s - loss: 0.8212 - 4s/epoch - 9ms/step
# Epoch 87/100
# 439/439 - 4s - loss: 0.8207 - 4s/epoch - 8ms/step
# Epoch 88/100
# 439/439 - 3s - loss: 0.8294 - 3s/epoch - 7ms/step
# Epoch 89/100
# 439/439 - 3s - loss: 0.8262 - 3s/epoch - 7ms/step
# Epoch 90/100
# 439/439 - 3s - loss: 0.8207 - 3s/epoch - 8ms/step
# Epoch 91/100
# 439/439 - 4s - loss: 0.8261 - 4s/epoch - 8ms/step
# Epoch 92/100
# 439/439 - 3s - loss: 0.8186 - 3s/epoch - 7ms/step
# Epoch 93/100
# 439/439 - 3s - loss: 0.8295 - 3s/epoch - 7ms/step
# Epoch 94/100
# 439/439 - 3s - loss: 0.8200 - 3s/epoch - 7ms/step
# Epoch 95/100
# 439/439 - 4s - loss: 0.8257 - 4s/epoch - 10ms/step
# Epoch 96/100
# 439/439 - 3s - loss: 0.8153 - 3s/epoch - 7ms/step
# Epoch 97/100
# 439/439 - 3s - loss: 0.8253 - 3s/epoch - 7ms/step
# Epoch 98/100
# 439/439 - 3s - loss: 0.8252 - 3s/epoch - 7ms/step
# Epoch 99/100
# 439/439 - 4s - loss: 0.8232 - 4s/epoch - 9ms/step
# Epoch 100/100
# 439/439 - 3s - loss: 0.8234 - 3s/epoch - 7ms/step

# %%
trainPredict = pd.DataFrame(model.predict(train_X_sc))
testPredict = pd.DataFrame(model.predict(test_X_sc))
# Out:
# 110/110 [==============================] - 1s 3ms/step
# 37/37 [==============================] - 0s 3ms/step

# %%
# invert predictions
trainPredict = sc2.inverse_transform(trainPredict)
testPredict = sc2.inverse_transform(testPredict)

# %%
trainPredict = pd.DataFrame(trainPredict)
testPredict = pd.DataFrame(testPredict)

# %%
#invert train y and test y
train_y_plot = pd.DataFrame(sc2.inverse_transform(train_y_sc))
test_y_plot = pd.DataFrame(sc2.inverse_transform(test_y_sc))

# %%
testPredict=abs(testPredict)

# %%
trainScore = math.sqrt(mean_squared_error(train_y_plot, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(test_y_plot, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 33.99 RMSE
# Test Score: 42.07 RMSE

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(train_y_plot, trainPredict)
# Out:
# 0.20755825936749683

# %%
mean_absolute_error(train_y_plot, trainPredict)

# %%
trainPredict=abs(trainPredict)

# %%
# plot baseline and predictions
plt.plot(train_y_plot)
plt.plot(trainPredict)
plt.show()

# %%
# plot baseline and predictions
plt.plot(test_y_plot)
plt.plot(testPredict)
plt.show()

# %%
# Calculate MAPE
mape_train = mape(train_y_plot+0.01, trainPredict)
mape_test = mape(test_y_plot+0.01, testPredict)
print("MAPE of training set:",np.round(mape_train,2), "MAPE of testing set:", np.round(mape_test,2))
# Out:
# MAPE of training set: 127.14 MAPE of testing set: 172.98

# %%
test_y_plot.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/test_y_plot.csv')
testPredict.to_csv('/content/drive/MyDrive/Colab Notebooks/Electric Vehicle/testPredict.csv')

# %% [markdown]
# GRU

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model1 = keras.Sequential()
model1.add(layers.GRU(64, input_shape=(1, 6)))
model1.add(layers.BatchNormalization())
model1.add(layers.Dense(10))
print(model1.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                13824
#
#  batch_normalization_18 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_21 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 14,730
# Trainable params: 14,602
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
model1.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="sgd",
    metrics=["accuracy"],
)

# %%
model.fit(
    train_X_sc, train_y_sc, validation_data=(test_X_sc, test_y_sc), batch_size=4, epochs=100)
# Out:
# Epoch 1/100
# 857/857 [==============================] - 13s 16ms/step - loss: 0.4203 - val_loss: 0.8063
# Epoch 2/100
# 857/857 [==============================] - 13s 15ms/step - loss: 0.3933 - val_loss: 0.8850
# Epoch 3/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4398 - val_loss: 1.0001
# Epoch 4/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4295 - val_loss: 0.8009
# Epoch 5/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4089 - val_loss: 0.8817
# Epoch 6/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4299 - val_loss: 0.9231
# Epoch 7/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4300 - val_loss: 1.0032
# Epoch 8/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4138 - val_loss: 0.8783
# Epoch 9/100
# 857/857 [==============================] - 11s 13ms/step - loss: 0.4325 - val_loss: 1.0287
# Epoch 10/100
# 857/857 [==============================] - 15s 17ms/step - loss: 0.4296 - val_loss: 0.9961
# Epoch 11/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4107 - val_loss: 0.9742
# Epoch 12/100
# 857/857 [==============================] - 14s 17ms/step - loss: 0.4142 - val_loss: 0.8565
# Epoch 13/100
# 857/857 [==============================] - 11s 13ms/step - loss: 0.4256 - val_loss: 0.9117
# Epoch 14/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.3978 - val_loss: 0.9615
# Epoch 15/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4287 - val_loss: 0.8222
# Epoch 16/100
# 857/857 [==============================] - 16s 18ms/step - loss: 0.4254 - val_loss: 0.8593
# Epoch 17/100
# 857/857 [==============================] - 15s 17ms/step - loss: 0.4108 - val_loss: 0.8638
# Epoch 18/100
# 857/857 [==============================] - 15s 17ms/step - loss: 0.4251 - val_loss: 1.0000
# Epoch 19/100
# 857/857 [==============================] - 15s 18ms/step - loss: 0.4003 - val_loss: 0.8508
# Epoch 20/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4105 - val_loss: 0.8554
# Epoch 21/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4116 - val_loss: 0.9848
# Epoch 22/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4203 - val_loss: 0.9246
# Epoch 23/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4133 - val_loss: 0.9934
# Epoch 24/100
# 857/857 [==============================] - 9s 10ms/step - loss: 0.4222 - val_loss: 0.8549
# Epoch 25/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4137 - val_loss: 0.8911
# Epoch 26/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4195 - val_loss: 0.7744
# Epoch 27/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4081 - val_loss: 1.0192
# Epoch 28/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4152 - val_loss: 1.1913
# Epoch 29/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4212 - val_loss: 0.8384
# Epoch 30/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4144 - val_loss: 0.9373
# Epoch 31/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4248 - val_loss: 1.0203
# Epoch 32/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4117 - val_loss: 0.9729
# Epoch 33/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4219 - val_loss: 0.8088
# Epoch 34/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4041 - val_loss: 0.8571
# Epoch 35/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4284 - val_loss: 0.8683
# Epoch 36/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4042 - val_loss: 0.8849
# Epoch 37/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4347 - val_loss: 0.8303
# Epoch 38/100
# 857/857 [==============================] - 9s 10ms/step - loss: 0.4099 - val_loss: 0.9923
# Epoch 39/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4167 - val_loss: 0.8189
# Epoch 40/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4272 - val_loss: 0.8931
# Epoch 41/100
# 857/857 [==============================] - 9s 10ms/step - loss: 0.4195 - val_loss: 0.9534
# Epoch 42/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4095 - val_loss: 0.9944
# Epoch 43/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4375 - val_loss: 0.9609
# Epoch 44/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4071 - val_loss: 0.9462
# Epoch 45/100
# 857/857 [==============================] - 12s 14ms/step - loss: 0.4229 - val_loss: 0.9925
# Epoch 46/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4210 - val_loss: 0.9183
# Epoch 47/100
# 857/857 [==============================] - 12s 14ms/step - loss: 0.4161 - val_loss: 1.0124
# Epoch 48/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4247 - val_loss: 0.8600
# Epoch 49/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4200 - val_loss: 0.9790
# Epoch 50/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4249 - val_loss: 0.9352
# Epoch 51/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4009 - val_loss: 0.9689
# Epoch 52/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4211 - val_loss: 0.8496
# Epoch 53/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4120 - val_loss: 0.9030
# Epoch 54/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4147 - val_loss: 0.9726
# Epoch 55/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4219 - val_loss: 0.8670
# Epoch 56/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4144 - val_loss: 1.0484
# Epoch 57/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4353 - val_loss: 0.8924
# Epoch 58/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4192 - val_loss: 0.9213
# Epoch 59/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4143 - val_loss: 0.9958
# Epoch 60/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4122 - val_loss: 0.8856
# Epoch 61/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.3985 - val_loss: 1.0534
# Epoch 62/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4036 - val_loss: 0.8244
# Epoch 63/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4094 - val_loss: 0.9060
# Epoch 64/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4043 - val_loss: 0.8818
# Epoch 65/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4098 - val_loss: 0.9849
# Epoch 66/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4305 - val_loss: 0.9581
# Epoch 67/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4153 - val_loss: 0.9360
# Epoch 68/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4170 - val_loss: 0.8023
# Epoch 69/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4230 - val_loss: 0.9207
# Epoch 70/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.3919 - val_loss: 0.9568
# Epoch 71/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4058 - val_loss: 0.8713
# Epoch 72/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4082 - val_loss: 1.0575
# Epoch 73/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4199 - val_loss: 1.0247
# Epoch 74/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4115 - val_loss: 0.9389
# Epoch 75/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4182 - val_loss: 0.9676
# Epoch 76/100
# 857/857 [==============================] - 11s 13ms/step - loss: 0.4130 - val_loss: 0.9295
# Epoch 77/100
# 857/857 [==============================] - 14s 16ms/step - loss: 0.4144 - val_loss: 1.0074
# Epoch 78/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4210 - val_loss: 0.9002
# Epoch 79/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4276 - val_loss: 0.9717
# Epoch 80/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4220 - val_loss: 0.9622
# Epoch 81/100
# 857/857 [==============================] - 17s 19ms/step - loss: 0.4124 - val_loss: 0.8752
# Epoch 82/100
# 857/857 [==============================] - 11s 13ms/step - loss: 0.4189 - val_loss: 0.7669
# Epoch 83/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4348 - val_loss: 0.8386
# Epoch 84/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4291 - val_loss: 0.9377
# Epoch 85/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4194 - val_loss: 0.8672
# Epoch 86/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4212 - val_loss: 0.8546
# Epoch 87/100
# 857/857 [==============================] - 9s 10ms/step - loss: 0.4054 - val_loss: 1.0214
# Epoch 88/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.3986 - val_loss: 0.9926
# Epoch 89/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4140 - val_loss: 0.9898
# Epoch 90/100
# 857/857 [==============================] - 9s 11ms/step - loss: 0.4221 - val_loss: 0.9914
# Epoch 91/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4366 - val_loss: 0.9740
# Epoch 92/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4076 - val_loss: 0.9959
# Epoch 93/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4277 - val_loss: 0.8412
# Epoch 94/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4202 - val_loss: 0.8834
# Epoch 95/100
# 857/857 [==============================] - 11s 13ms/step - loss: 0.4192 - val_loss: 0.9577
# Epoch 96/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4056 - val_loss: 0.9795
# Epoch 97/100
# 857/857 [==============================] - 10s 11ms/step - loss: 0.4187 - val_loss: 0.9727
# Epoch 98/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4217 - val_loss: 0.8060
# Epoch 99/100
# 857/857 [==============================] - 10s 12ms/step - loss: 0.4189 - val_loss: 0.9220
# Epoch 100/100
# 857/857 [==============================] - 11s 12ms/step - loss: 0.4243 - val_loss: 0.7865

# %%
trainPredict = pd.DataFrame(model1.predict(train_X_sc))
testPredict = pd.DataFrame(model1.predict(test_X_sc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-434-bc1a48e69181> in <cell line: 1>()
# ----> 1 trainPredict = pd.DataFrame(model1.predict(train_X_sc))
#       2 testPredict = pd.DataFrame(model1.predict(test_X_sc))
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_20" is incompatible with the layer: expected shape=(None, 28, 28), found shape=(None, 6)

# %%
#for i in range(10):
#    result = tf.argmax(model1.predict(tf.expand_dims(test_X_sc[i], 0)), axis=1)
#    print(result.numpy(), test_y_sc[i])

# %%
trainPredict = sc2.inverse_transform(trainPredict)
testPredict = sc2.inverse_transform(testPredict)

# %%
trainPredict = pd.DataFrame(trainPredict)
testPredict = pd.DataFrame(testPredict)

# %%
train_y_plot = pd.DataFrame(sc2.inverse_transform(train_y_sc))
test_y_plot = pd.DataFrame(sc2.inverse_transform(test_y_sc))

# %%
testPredict=abs(testPredict)

# %%
trainScore = math.sqrt(mean_squared_error(train_y_plot, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(test_y_plot, testPredict))
print('Test Score: %.2f RMSE' % (testScore))

# %%
# plot baseline and predictions
plt.plot(train_y_plot)
plt.plot(trainPredict)
plt.show()

# %%
# plot baseline and predictions
plt.plot(test_y_plot)
plt.plot(testPredict)
plt.show()
